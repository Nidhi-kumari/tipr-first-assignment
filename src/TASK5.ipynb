# %%
import matplotlib.pyplot as plt
import pickle
def plot(filename1,filename2):
    f = open(filename1, "rb")
    value1 = pickle.load(f)
    value2 = pickle.load(f)
    value3 = pickle.load(f)
    f.close()
    
    f2 = open(filename2, "rb")
    value4 = pickle.load(f2)
    value5 = pickle.load(f2)
    value6 = pickle.load(f2)
    f2.close()
    
    #plt.figure(1)                # the first figure
    #plt.subplot(211)             # the first subplot in the first figure
    plt.plot(*zip(*sorted(value1.items())),'r')
    plt.plot(*zip(*sorted(value4.items())),'g' ,label="library")
    #plt.xlabel("dimension")
    plt.legend()
    plt.ylabel("accuracy")
    plt.xlabel("dimension")
    '''
    plt.subplot(212)             # the second subplot in the first figure
    plt.plot(*zip(*sorted(value2.items())),'b',label="macro")
    plt.plot(*zip(*sorted(value3.items())),'g' ,label="micro")
    plt.plot(*zip(*sorted(value5.items())),'r',label="macro")
    plt.plot(*zip(*sorted(value6.items())),'p' ,label="micro")
    plt.legend()
    plt.xlabel("dimension")
    plt.ylabel("f1_score")
    #plt.subplot(223)             # the second subplot in the first figure
    #plt.plot(dimensions,accuraciesnb)
    #plt.subplot(224)             # the second subplot in the first figure
    #plt.plot(dimensions,f1scoresnb)
    plt.subplots_adjust(top=0.92, bottom=0.01, left=0.10, right=0.95, hspace=0.25,wspace=0.35)
   '''
    plt.show()

# %%
plot("graphData/pubmed/evaluation_pubmedKNN","graphData/pubmed/evaluation_pubmedKNNLIB")

# %%
plot("graphData/evaluation_twitterKNN","graphData/evaluation_twitterKNNLIB")

# %%
plot("graphData/dolphins/evaluation_dolphinsKNN","graphData/dolphins/evaluation_dolphinsKNNLIB")

# %%
plot("graphData/pubmed/evaluation_pubmedNBS","graphData/pubmed/evaluation_pubmedNBLIB")

# %%
plot("graphData/evaluation_twitterNBS","graphData/evaluation_twitterNBLIB")
