# %%
import matplotlib.pyplot as plt
import pickle
def plot(filename):
    f = open(filename, "rb")
    value1 = pickle.load(f)
    value2 = pickle.load(f)
    value3 = pickle.load(f)
    f.close()
    
    plt.figure(1)                # the first figure
    plt.subplot(211)             # the first subplot in the first figure
    plt.plot(*zip(*sorted(value1.items())),'r')
    #plt.xlabel("dimension")
    plt.ylabel("accuracy")
    
    plt.subplot(212)             # the second subplot in the first figure
    plt.plot(*zip(*sorted(value2.items())),'b',label="macro")
    plt.plot(*zip(*sorted(value3.items())),'g' ,label="micro")
    plt.legend()
    plt.xlabel("dimension")
    plt.ylabel("f1_score")
    #plt.subplot(223)             # the second subplot in the first figure
    #plt.plot(dimensions,accuraciesnb)
    #plt.subplot(224)             # the second subplot in the first figure
    #plt.plot(dimensions,f1scoresnb)
    plt.subplots_adjust(top=0.92, bottom=0.01, left=0.10, right=0.95, hspace=0.25,wspace=0.35)
   
    plt.show()

# %%
plot("graphData/pubmed/evaluation_pubmedKNNPCA")

# %%
plot("graphData/pubmed/evaluation_pubmedKNN")

# %%
plot("graphData/pubmed/evaluation_pubmedKNNLIB")

# %%
plot("graphData/pubmed/evaluation_pubmedNBLIB")

# %%
plot("graphData/pubmed/evaluation_pubmedLSH")

# %%
plot("graphData/pubmed/evaluation_pubmedNBS")

# %%
plot("graphData/dolphins/evaluation_dolphinsKNN")

# %%
plot("graphData/dolphins/evaluation_dolphinsKNNLIB")

# %%
plot("graphData/dolphins/evaluation_dolphinsLSH")

# %%
plot("graphData/dolphins/evaluation_dolphinsKNNPCA")

# %%
plot("graphData/evaluation_twitterKNN")

# %%
plot("graphData/evaluation_twitterNBS")

# %%
plot("graphData/evaluation_twitterKNNLIB")

# %%
plot("graphData/evaluation_twitterNBLIB")

# %%
plot("graphData/evaluation_twitterLSH")

# %%
plot("graphData/evaluation_twitterKNNPCA")
